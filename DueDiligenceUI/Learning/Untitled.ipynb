# %%
import os
import ntpath

# %%
print(ntpath.os)

# %%
os.name

# %%
os.path.realpath(__file__)

# %% [markdown]
# import pathlig

# %%
import pathlib

# %%
pathlib.Path(__file__).parent

# %%
os.path.join(os.path.dirname(__file__), 'my_file')

# %%
from os import listdir
from os.path import isfile, join
dirpath = 'C:\Dev\Work\DueDiligence_Material\DueDil\DueDiligenceUI\Articles_Repo'
onlyfiles = [f for f in listdir(dirpath) if isfile(join(dirpath, f))]
onlyfiles
# Out:
# ['1.pdf',
#  'Factiva-10September20191007 (1).pdf',
#  'Factiva-10September20191159.pdf',
#  'Factiva-10September20191211.pdf']

# %%
# importing required modules 
import PyPDF2 

print(join(dirpath, onlyfiles[3]))

# creating a pdf file object 
pdfFileObj = open(join(dirpath, onlyfiles[3]), 'rb') 
  
# creating a pdf reader object 
pdfReader = PyPDF2.PdfFileReader(pdfFileObj, strict=False) 
  
# printing number of pages in pdf file 
print(pdfReader.numPages) 
  
# creating a page object 
pageObj = pdfReader.getPage(0) 
  
# extracting text from page 
print(pageObj.extractText()) 
  
# closing the pdf file object 
pdfFileObj.close()

# %%
pip install PyPDF2

# %%
pip install tabula-py

# %%
import tabula
import pandas as pd

# %%
print(join(dirpath, onlyfiles[3]))
df = tabula.read_pdf(join(dirpath, onlyfiles[0]),multiple_tables=True)
df

# %%
pip install pdftotext

# %%
import pdftotext
with open(join(dirpath, onlyfiles[0]), "rb") as f:
    pdf = pdftotext.PDF(f)
for page in pdf:
    print(page)

# %%
pip install pdfminer

# %%
pip install pdfminer.six
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/8a/fd/6e8746e6965d1a7ea8e97253e3d79e625da5547e8f376f88de5d024bacb9/pdfminer.six-20181108-py2.py3-none-any.whl
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import io
from os.path import join
 
from pdfminer.converter import TextConverter
from pdfminer.pdfinterp import PDFPageInterpreter
from pdfminer.pdfinterp import PDFResourceManager
from pdfminer.pdfpage import PDFPage

resource_manager = PDFResourceManager()
fake_file_handle = io.StringIO()
converter = TextConverter(resource_manager, fake_file_handle)
page_interpreter = PDFPageInterpreter(resource_manager, converter)
 
with open(join(dirpath, onlyfiles[1]), 'rb') as fh:
    for page in PDFPage.get_pages(fh,caching=True,check_extractable=True):
        page_interpreter.process_page(page)
        text = fake_file_handle.getvalue()
    print(text)
# Out:
# Page1of3©2019Factiva,Inc.Allrightsreserved.Thelegalassault.....................................................................................................................................................2Page2of3©2019Factiva,Inc.Allrightsreserved.ThelegalassaultThelegalassault919words9September2019DeccanChronicleDECCLEEnglish©Copyright2019.DeccanChronicleHoldingsLtd.On8thofJanuary,2019,almosttwoandahalfyearsafteritwasoriginallyintroduced,theLokSabhapassedtheCitizenship(Amendment)Bill,2016.Thiswasthefirstofthreestepsthatneedtobecompletedforthisproposedlegislationtobecomethelawoftheland.InorderfortheamendmentsproposedintheBilltobecomeoperative,thegovernmentmustsecurethenecessarysupportintheUpperHouseofParliamentfortheBill,andtheBillmustreceivePresidentialAscent.ThereareseveralpotentialissuesthatplaguethisBillandtheamendmentsproposedinit,chiefamongwhichistheproposedamendmenttothedefinitionof“illegalmigrant”undertheCitizenshipAct,1955.ThisActoriginallydefinedillegalmigrantstoincludea
# ...

# %%
pip install pdfminer3
# Out:
# ...
#   Stored in directory: C:\Users\hemanshu.waghulde\AppData\Local\pip\Cache\wheels\27\35\61\7d4c0c350683751100186de869681db04d6f2c5ab603eb0510
# Successfully built pdfminer3
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pdfminer3.layout import LAParams, LTTextBox
from pdfminer3.pdfpage import PDFPage
from pdfminer3.pdfinterp import PDFResourceManager
from pdfminer3.pdfinterp import PDFPageInterpreter
from pdfminer3.converter import PDFPageAggregator

resource_manager = PDFResourceManager()
fake_file_handle = io.StringIO()
converter = TextConverter(resource_manager, fake_file_handle)
page_interpreter = PDFPageInterpreter(resource_manager, converter)

with open(join(dirpath, onlyfiles[3]), 'rb') as fh:

    for page in PDFPage.get_pages(fh,
                                  caching=True,
                                  check_extractable=True):
        page_interpreter.process_page(page)

    text = fake_file_handle.getvalue()

# close open handles
converter.close()
fake_file_handle.close()

print(text)
# Out:
# Page1of1©2019Factiva,Inc.Allrightsreserved.RahultargetsPMonRafale,dareshimforadebate304words6September2019DeccanHeraldDECHEREnglishCopyright2019.ThePrinters(Mysore)PrivateLtd.Mumbai/DhuleTargettingprimeministerNarendraModiontheRafaledeal,CongresspresidentRahulGandhionFridaydaredhimforapublicdebateoncorruption."Iamaskingforadebateoncorruption,lethimcomeanddebatewithme,"GandhisaidaddressingarallyattheMMRDAgroundsattheBandraKurlaComplexinMumbaihere.ReferringtoModias"chowkidar"inhisspeechseveraltimes,hesaidthat-"chowkidarchorhinahi,darpokbhihai"-andpointedoutthatintheParliament,theprimeministerhasrefusedtoanswerthepointedquestionsofCongressontheRafaledeal.Duringtheday,Gandhiaddressedtworallies-inDhuleinKhandesh-NorthMaharashtraandMumbai,duringwhichhespokeontheRafaleissue."DidAnilAmbanimakeMirageandSukhois?,"GandhisaidinthebackdropofthePulwamaterrorattacksandIndia'sstrikeinterrorcampsinPakistanandPakistan-occupied-Kashmir.HewantedtoknowwhythemanufacturingcontractwasgiventoAnilAmbani'scomp
# ...

# %%
import io

import pdfminer
from pdfminer.converter import TextConverter
from pdfminer.pdfinterp import PDFPageInterpreter
from pdfminer.pdfinterp import PDFResourceManager
from pdfminer.pdfpage import PDFPage
# Perform layout analysis for all text
laparams = pdfminer.layout.LAParams()
setattr(laparams, 'all_texts', True)

def extract_text_from_pdf(pdf_path):
    resource_manager = PDFResourceManager()
    fake_file_handle = io.StringIO()
    converter = TextConverter(resource_manager, fake_file_handle, laparams=laparams)
    page_interpreter = PDFPageInterpreter(resource_manager, converter)

    with open(pdf_path, 'rb') as fh:
        for page in PDFPage.get_pages(fh, 
                                      caching=True,
                                      check_extractable=True):
            page_interpreter.process_page(page)

        text = fake_file_handle.getvalue()

    # close open handles
    converter.close()
    fake_file_handle.close()

    if text:
        return text


text = extract_text_from_pdf(join(dirpath, onlyfiles[3]))
print(text)
# Out:
# Rahul targets PM on Rafale, dares him for a debate
# 304 words
# 6 September 2019
# Deccan Herald
# DECHER
# English
# Copyright 2019. The Printers (Mysore) Private Ltd.
# Mumbai/ Dhule
#
# Targetting prime minister Narendra Modi on the Rafale deal, Congress president Rahul Gandhi on Friday
# dared him for a public debate on corruption."I am asking for a debate on corruption, let him come and debate
# with me," Gandhi said addressing a rally at the MMRDA grounds at the Bandra Kurla Complex in Mumbai
# here.
#
# Referring to Modi as "chowkidar" in his speech several times, he said that - "chowkidar chor hi nahi, darpok
# bhi hai" - and pointed out that in the Parliament, the prime minister has refused to answer the pointed
# questions of Congress on the Rafale deal.
#
# During the day, Gandhi addressed two rallies - in Dhule in Khandesh-North Maharashtra and Mumbai, during
# which he spoke on the Rafale issue."Did Anil Ambani make Mirage and Sukhois?, " Gandhi said in the
# ...

# %%
from nltk.corpus import stopwords

# %%
# Out:
# ...
#   Stored in directory: C:\Users\hemanshu.waghulde\AppData\Local\pip\Cache\wheels\2c\19\c6\bf38e867cb6e75999e3ff80302eb27bdf488b333efadfbfed7
# ...
#   Stored in directory: C:\Users\hemanshu.waghulde\AppData\Local\pip\Cache\wheels\5f\ea\fb\5b1a947b369724063b2617011f1540c44eb00e28c3d2ca8692
# Successfully built gensim smart-open
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an EnvironmentError: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\hemanshu.waghulde\\AppData\\Local\\Continuum\\anaconda3\\Lib\\site-packages\\gensim-3.8.0.dist-info\\RECORD'
# Consider using the `--user` option or check the permissions.

# %%
pip install gensim
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
import gensim
from nltk.corpus import abc

# %%
abc.sents()
# Out:
# [['PM', 'denies', 'knowledge', 'of', 'AWB', 'kickbacks', 'The', 'Prime', 'Minister', 'has', 'denied', 'he', 'knew', 'AWB', 'was', 'paying', 'kickbacks', 'to', 'Iraq', 'despite', 'writing', 'to', 'the', 'wheat', 'exporter', 'asking', 'to', 'be', 'kept', 'fully', 'informed', 'on', 'Iraq', 'wheat', 'sales', '.'], ['Letters', 'from', 'John', 'Howard', 'and', 'Deputy', 'Prime', 'Minister', 'Mark', 'Vaile', 'to', 'AWB', 'have', 'been', 'released', 'by', 'the', 'Cole', 'inquiry', 'into', 'the', 'oil', 'for', 'food', 'program', '.'], ...]

# %%
import gensim

# Load Google's pre-trained Word2Vec model.
model = gensim.models.KeyedVectors.load_word2vec_format('C:\Dev\Work\DueDiligence_Material\DueDil\DueDiligenceUI\Models\GoogleNews-vectors-negative300.bin', binary=True)
vocab = list(model.vocab.keys())
vocab[:1]
# Out:
# ['</s>']

# %%
wordsInVocab = len(vocab)
print (wordsInVocab)
print (model.similarity('this', 'is'))
print (model.similarity('post', 'book'))
# Out:
# 3000000
# 0.40797037
# 0.057204388

# %%
model['this']
# Out:
# array([ 0.109375  ,  0.140625  , -0.03173828,  0.16601562, -0.07128906,
#         0.01586914, -0.00311279, -0.08496094, -0.04858398,  0.05566406,
#        -0.08251953, -0.02404785, -0.00665283,  0.03686523, -0.05029297,
#        -0.02941895,  0.11376953, -0.06787109,  0.05639648, -0.07568359,
#        -0.03857422,  0.09716797, -0.04418945, -0.12207031,  0.140625  ,
#         0.08496094,  0.09667969,  0.07470703, -0.0039978 ,  0.17285156,
#        -0.06933594,  0.08886719,  0.03808594, -0.00061417,  0.01184082,
#         0.00164032, -0.20898438, -0.08251953,  0.08984375,  0.07910156,
#         0.12353516, -0.01867676,  0.03039551,  0.04711914,  0.06542969,
#        -0.01251221,  0.00152588,  0.10644531, -0.01531982, -0.04199219,
#         0.16796875,  0.05175781,  0.07470703,  0.08251953,  0.01721191,
#         0.01599121,  0.02734375, -0.03686523,  0.08105469, -0.06445312,
#        -0.08984375,  0.10742188,  0.01153564, -0.13671875,  0.05151367,
# ...

# %%
model= gensim.models.Word2Vec(abc.sents())

# %%
X= list(model.wv.vocab)
X
# Out:
# ['PM',
#  'denies',
#  'knowledge',
#  'of',
#  'AWB',
#  'kickbacks',
#  'The',
#  'Prime',
#  'Minister',
#  'has',
#  'denied',
#  'he',
#  'knew',
#  'was',
#  'paying',
#  'to',
#  'Iraq',
#  'despite',
#  'writing',
#  'the',
#  'wheat',
#  'exporter',
#  'asking',
#  'be',
#  'kept',
#  'fully',
#  'informed',
#  'on',
#  'sales',
#  '.',
#  'Letters',
#  'from',
#  'John',
#  'Howard',
#  'and',
#  'Deputy',
#  'Mark',
#  'Vaile',
#  'have',
#  'been',
#  'released',
#  'by',
#  'Cole',
#  'inquiry',
#  'into',
#  'oil',
#  'for',
#  'food',
#  'program',
#  'In',
#  'one',
#  'letters',
#  'Mr',
#  'asks',
#  'managing',
#  'director',
#  'Andrew',
#  'Lindberg',
#  'remain',
#  'in',
#  'close',
#  'contact',
#  'with',
#  'Government',
#  'Opposition',
#  "'",
#  's',
#  'Gavan',
#  'O',
#  'Connor',
#  'says',
#  'letter',
#  'sent',
#  '2002',
#  ',',
#  'same',
#  'time',
#  'though',
#  'a',
#  'trucking',
#  'company',
#  'He',
#  'can',
#  'longer',
#  'wipe',
# ...

# %%
data=model.most_similar('science')
print(data)
# Out:
# C:\Users\hemanshu.waghulde\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('law', 0.9352298974990845), ('agriculture', 0.9266632199287415), ('policy', 0.9264189004898071), ('general', 0.9260243773460388), ('media', 0.916580080986023), ('practice', 0.9158788919448853), ('discussion', 0.9129656553268433), ('board', 0.9088324308395386), ('Cooper', 0.9086107015609741), ('Crean', 0.9081443548202515)]

# %%
pip install EventRegistry
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/cc/44/ebf2b9b415aaa38b34f7adad24ffe1c04964d84f848bd8507390512e9ccb/eventregistry-8.6.1.tar.gz
# ...
#   Stored in directory: C:\Users\hemanshu.waghulde\AppData\Local\pip\Cache\wheels\c4\c7\e3\913d9e9e76d2a7fbda635e0003dec2a11d99eb491990ac82c7
# Successfully built EventRegistry
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from datetime import date, timedelta
date.today()-timedelta(days=30)
# Out:
# datetime.date(2019, 9, 2)

# %%
f4a005ab-a24f-487e-bff4-f39b1b2ba6c2
# Out:
#   File "<ipython-input-4-e890b9199c76>", line 1
#     f4a005ab-a24f-487e-bff4-f39b1b2ba6c2
#                       ^
# SyntaxError: invalid token

# %%
from eventregistry import *
er = EventRegistry(apiKey = "")
q = QueryArticlesIter(
    keywords = "Thomas Cook Group PLC",
    dataType = ["news", "blog"],
    lang = "eng",
    dateStart=date.today()-timedelta(days=30),
    dateEnd=date.today())
# obtain at most 500 newest articles or blog posts
for art in q.execQuery(er, sortBy = "date", maxItems = 5):
    print(art["body"] + '\n@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@\n')
# Out:
# using user provided API key for making requests
# Event Registry host: http://eventregistry.org
# Text analytics host: http://analytics.eventregistry.org
# BANKRUPT. Investigations are launched after the collapse of debt-plagued British travel giant Thomas Cook. Photo from Shutterstock
#
# LONDON, United Kingdom - Britain launched an investigation on Tuesday, October 1, into the auditors who signed off on accounts for the now-bankrupt holiday giant Thomas Cook, as the company's French branch went into receivership and its Belgian division collapsed.
#
# The Financial Reporting Council (FRC) said in a statement that it will examine whether accountancy firm EY - which replaced PwC as Thomas Cook's auditors in 2017 - acted properly in scrutinizing its books.
#
# "The FRC has commenced an investigation into the audit by EY of the financial statements of Thomas Cook Group Plc for the year ended 30 September 2018," it said.
#
# ...

# %%
import json

# %%
y = json.loads('{"uri": "1280625638", "lang": "eng"}')
print(y["uri"])
# Out:
# 1280625638

# %%
z = {'uri': '1280625638', 'lang': 'eng'}
json.loads(z.replace("'", ""))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-236a5787856d> in <module>
#       1 z = {'uri': '1280625638', 'lang': 'eng'}
# ----> 2 json.loads(z.replace("'", ""))
#
# AttributeError: 'dict' object has no attribute 'replace'

# %%
json_string = json.dumps("{'uri': '1280625638', 'lang': 'eng'}")
print(json_string)
# Out:
# "{'uri': '1280625638', 'lang': 'eng'}"

# %%
import ast
data_dict = ast.literal_eval("{'uri': '1280612631', 'lang': 'eng', 'isDuplicate': False, 'date': '2019-10-01', 'time': '13:56:00', 'dateTime': '2019-10-01T13:56:00Z', 'dataType': 'news', 'sim': 0, 'url': 'https://english.mubasher.info/news/3538120/Thomas-Cook-owes-Turkish-tourism-sector-EUR-350m', 'title': 'Thomas Cook owes Turkish tourism sector EUR 350m', 'body': 'Test', 'source': {'uri': 'english.mubasher.info', 'dataType': 'news', 'title': 'english.mubasher.info'}, 'authors': [], 'image': 'https://static.mubasher.info/File.Story_Image/31836ab6a007ecce189069610b14604d/640.jpg', 'eventUri': None, 'sentiment': 0.0117647058823529, 'wgt': 307634160}")
print(data_dict["body"])
# Out:
# Test

# %%
from gensim.test.utils import common_texts
common_texts
# Out:
# [['human', 'interface', 'computer'],
#  ['survey', 'user', 'computer', 'system', 'response', 'time'],
#  ['eps', 'user', 'interface', 'system'],
#  ['system', 'human', 'system', 'eps'],
#  ['user', 'response', 'time'],
#  ['trees'],
#  ['graph', 'trees'],
#  ['graph', 'minors', 'trees'],
#  ['graph', 'minors', 'survey']]
